# %% [markdown]
# # Data Information : Human Activity Recognition

# %% [markdown]
# ## Overview
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.

# %% [markdown]
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.

# %% [markdown]
# ## Feature Names

# %% [markdown]
# ### Feature X

# %% [markdown]
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was saperated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean

# %% [markdown]
# ###  Y_Labels(Encoded)

# %% [markdown]
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__

# %% [markdown]
# ## Train and Test Data Split

# %% [markdown]
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___training data___ and remaining ___30%___ subjects recordings were taken for ___test data___

# %% [markdown]
# ## Data Files Information

# %% [markdown]
# ### Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'
#
# ### Data Size :
# > 27 MB

# %% [markdown]
# ## Quick review of the dataset

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.

# %% [markdown]
# ## Problem Framework

# %% [markdown]
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
# Given a new datapoint we have to predict the Activity

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Obtaining Data and Splitting the Data

# %%
train = pd.read_csv('UCI_HAR_dataset/csv_files/train.csv')
test = pd.read_csv('UCI_HAR_dataset/csv_files/test.csv')
print(train.shape, test.shape)
# Out:
# (7352, 564) (2947, 564)

# %%
train.head(3)
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2       0.279653      -0.019467      -0.113462     -0.995380     -0.967187
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
# 2     -0.978944     -0.996520     -0.963668     -0.977469     -0.938692  ...
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                 -0.112754                          0.030400
# 1                  0.053477                         -0.007435
# 2                 -0.118559                          0.177899
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.464761                          -0.018446
# 1                      -0.732626                           0.703511
# 2                       0.100699                           0.808529
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject  Activity  \
# 0          -0.841247           0.179941          -0.058627        1         5
# 1          -0.844788           0.180289          -0.054317        1         5
# 2          -0.848933           0.180637          -0.049118        1         5
#
#    ActivityName
# 0      STANDING
# 1      STANDING
# 2      STANDING
#
# [3 rows x 564 columns]

# %%
test.head(3)
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.257178      -0.023285      -0.014654     -0.938404     -0.920091
# 1       0.286027      -0.013163      -0.119083     -0.975415     -0.967458
# 2       0.275485      -0.026050      -0.118152     -0.993819     -0.969926
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.667683     -0.952501     -0.925249     -0.674302     -0.894088  ...
# 1     -0.944958     -0.986799     -0.968401     -0.945823     -0.894088  ...
# 2     -0.962748     -0.994403     -0.970735     -0.963483     -0.939260  ...
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                  0.006462                          0.162920
# 1                 -0.083495                          0.017500
# 2                 -0.034956                          0.202302
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.825886                           0.271151
# 1                      -0.434375                           0.920593
# 2                       0.064103                           0.145068
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject  Activity  \
# 0          -0.720009           0.276801          -0.057978        2         5
# 1          -0.698091           0.281343          -0.083898        2         5
# 2          -0.702771           0.280083          -0.079346        2         5
#
#    ActivityName
# 0      STANDING
# 1      STANDING
# 2      STANDING
#
# [3 rows x 564 columns]

# %% [markdown]
# ## get X_train and y_train from csv files

# %%
X_train = train.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_train = train.ActivityName

# %% [markdown]
# ## get X_test and y_test from test csv file

# %%
X_test = test.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_test = test.ActivityName

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# __We almost have same number of data from each user for each activity__

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __Conclusion: Our data is well balanced (almost)__

# %% [markdown]
# "Without domain knowledge EDA has no meaning, without EDA a problem has no soul."
#
# 1. Featuring Engineering from Domain Knowledge
# Static and Dynamic Activities
#
# In static activities (sit, stand, lie down) motion information will not be very useful.
# In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.
# 2. Stationary and Moving activities are completely different

# %% [markdown]
# ## Static vs Dynamic Activites

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False).add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\Love\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __Observations__ :
#
# 1. If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# 2. If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# 3. If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# 4. We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ## Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __Observations__:
#
# 1. If angleX,gravityMean > 0 then Activity is Laying.
# 2. We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# ## Applying T-sne on the Data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 3.187s...
# [t-SNE] Computed neighbors for 7352 samples in 59.992s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635854
# [t-SNE] Computed conditional probabilities in 0.102s
# [t-SNE] Iteration 50: error = 124.7052841, gradient norm = 0.0274965 (50 iterations in 7.311s)
# [t-SNE] Iteration 100: error = 107.3694534, gradient norm = 0.0297476 (50 iterations in 7.123s)
# [t-SNE] Iteration 150: error = 100.9844666, gradient norm = 0.0199758 (50 iterations in 3.721s)
# [t-SNE] Iteration 200: error = 97.5901489, gradient norm = 0.0173100 (50 iterations in 3.325s)
# [t-SNE] Iteration 250: error = 95.2966690, gradient norm = 0.0143061 (50 iterations in 3.651s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.296669
# [t-SNE] Iteration 300: error = 4.1174526, gradient norm = 0.0015639 (50 iterations in 3.100s)
# [t-SNE] Iteration 350: error = 3.2093525, gradient norm = 0.0010033 (50 iterations in 2.661s)
# [t-SNE] Iteration 400: error = 2.7809925, gradient norm = 0.0007148 (50 iterations in 2.734s)
# [t-SNE] Iteration 450: error = 2.5174689, gradient norm = 0.0005683 (50 iterations in 2.897s)
# [t-SNE] Iteration 500: error = 2.3341904, gradient norm = 0.0004758 (50 iterations in 3.445s)
# [t-SNE] Iteration 550: error = 2.1962414, gradient norm = 0.0004171 (50 iterations in 3.294s)
# [t-SNE] Iteration 600: error = 2.0869651, gradient norm = 0.0003663 (50 iterations in 3.241s)
# [t-SNE] Iteration 650: error = 1.9972315, gradient norm = 0.0003318 (50 iterations in 3.289s)
# [t-SNE] Iteration 700: error = 1.9215155, gradient norm = 0.0003020 (50 iterations in 3.540s)
# [t-SNE] Iteration 750: error = 1.8565842, gradient norm = 0.0002784 (50 iterations in 3.601s)
# [t-SNE] Iteration 800: error = 1.8000550, gradient norm = 0.0002579 (50 iterations in 3.594s)
# [t-SNE] Iteration 850: error = 1.7501638, gradient norm = 0.0002391 (50 iterations in 3.595s)
# [t-SNE] Iteration 900: error = 1.7056779, gradient norm = 0.0002247 (50 iterations in 3.014s)
# [t-SNE] Iteration 950: error = 1.6656140, gradient norm = 0.0002092 (50 iterations in 3.173s)
# [t-SNE] Iteration 1000: error = 1.6292977, gradient norm = 0.0002003 (50 iterations in 4.274s)
# [t-SNE] KL divergence after 1000 iterations: 1.629298
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\Love\anaconda3\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 1.799s...
# [t-SNE] Computed neighbors for 7352 samples in 55.568s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.061s
# [t-SNE] Iteration 50: error = 114.0118179, gradient norm = 0.0213440 (50 iterations in 8.141s)
# [t-SNE] Iteration 100: error = 98.0628357, gradient norm = 0.0162947 (50 iterations in 3.866s)
# [t-SNE] Iteration 150: error = 93.3257523, gradient norm = 0.0087563 (50 iterations in 3.177s)
# [t-SNE] Iteration 200: error = 91.3553314, gradient norm = 0.0077447 (50 iterations in 3.503s)
# [t-SNE] Iteration 250: error = 90.1780701, gradient norm = 0.0067834 (50 iterations in 4.834s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.178070
# [t-SNE] Iteration 300: error = 3.5794404, gradient norm = 0.0014585 (50 iterations in 5.439s)
# [t-SNE] Iteration 350: error = 2.8218400, gradient norm = 0.0007573 (50 iterations in 3.492s)
# [t-SNE] Iteration 400: error = 2.4413669, gradient norm = 0.0005255 (50 iterations in 3.647s)
# [t-SNE] Iteration 450: error = 2.2233696, gradient norm = 0.0004040 (50 iterations in 3.595s)
# [t-SNE] Iteration 500: error = 2.0782640, gradient norm = 0.0003338 (50 iterations in 3.204s)
# [t-SNE] Iteration 550: error = 1.9731126, gradient norm = 0.0002840 (50 iterations in 3.139s)
# [t-SNE] Iteration 600: error = 1.8918746, gradient norm = 0.0002470 (50 iterations in 3.461s)
# [t-SNE] Iteration 650: error = 1.8267934, gradient norm = 0.0002185 (50 iterations in 3.743s)
# [t-SNE] Iteration 700: error = 1.7727520, gradient norm = 0.0001985 (50 iterations in 3.375s)
# [t-SNE] Iteration 750: error = 1.7274044, gradient norm = 0.0001797 (50 iterations in 3.556s)
# [t-SNE] Iteration 800: error = 1.6883112, gradient norm = 0.0001660 (50 iterations in 3.252s)
# [t-SNE] Iteration 850: error = 1.6542499, gradient norm = 0.0001566 (50 iterations in 3.661s)
# [t-SNE] Iteration 900: error = 1.6242610, gradient norm = 0.0001418 (50 iterations in 3.869s)
# [t-SNE] Iteration 950: error = 1.5976490, gradient norm = 0.0001342 (50 iterations in 4.203s)
# [t-SNE] Iteration 1000: error = 1.5736879, gradient norm = 0.0001260 (50 iterations in 3.693s)
# [t-SNE] KL divergence after 1000 iterations: 1.573688
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\Love\anaconda3\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 2.499s...
# [t-SNE] Computed neighbors for 7352 samples in 61.890s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.329s
# [t-SNE] Iteration 50: error = 105.6787567, gradient norm = 0.0210668 (50 iterations in 6.656s)
# [t-SNE] Iteration 100: error = 90.8772888, gradient norm = 0.0123299 (50 iterations in 4.128s)
# [t-SNE] Iteration 150: error = 87.6218491, gradient norm = 0.0062332 (50 iterations in 3.675s)
# [t-SNE] Iteration 200: error = 86.3374863, gradient norm = 0.0043097 (50 iterations in 4.229s)
# [t-SNE] Iteration 250: error = 85.6002350, gradient norm = 0.0035915 (50 iterations in 4.259s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.600235
# [t-SNE] Iteration 300: error = 3.1392694, gradient norm = 0.0013868 (50 iterations in 3.868s)
# [t-SNE] Iteration 350: error = 2.4954634, gradient norm = 0.0006507 (50 iterations in 3.527s)
# [t-SNE] Iteration 400: error = 2.1740320, gradient norm = 0.0004248 (50 iterations in 3.811s)
# [t-SNE] Iteration 450: error = 1.9888682, gradient norm = 0.0003178 (50 iterations in 3.586s)
# [t-SNE] Iteration 500: error = 1.8705915, gradient norm = 0.0002536 (50 iterations in 3.493s)
# [t-SNE] Iteration 550: error = 1.7869575, gradient norm = 0.0002110 (50 iterations in 3.113s)
# [t-SNE] Iteration 600: error = 1.7241075, gradient norm = 0.0001828 (50 iterations in 3.661s)
# [t-SNE] Iteration 650: error = 1.6750072, gradient norm = 0.0001601 (50 iterations in 3.398s)
# [t-SNE] Iteration 700: error = 1.6354742, gradient norm = 0.0001437 (50 iterations in 3.507s)
# [t-SNE] Iteration 750: error = 1.6027535, gradient norm = 0.0001309 (50 iterations in 3.482s)
# [t-SNE] Iteration 800: error = 1.5751743, gradient norm = 0.0001196 (50 iterations in 3.484s)
# [t-SNE] Iteration 850: error = 1.5515208, gradient norm = 0.0001102 (50 iterations in 3.517s)
# [t-SNE] Iteration 900: error = 1.5314298, gradient norm = 0.0001033 (50 iterations in 3.275s)
# [t-SNE] Iteration 950: error = 1.5138236, gradient norm = 0.0000991 (50 iterations in 3.020s)
# [t-SNE] Iteration 1000: error = 1.4987222, gradient norm = 0.0000925 (50 iterations in 3.055s)
# [t-SNE] KL divergence after 1000 iterations: 1.498722
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\Love\anaconda3\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 1.771s...
# [t-SNE] Computed neighbors for 7352 samples in 51.045s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.307s
# [t-SNE] Iteration 50: error = 97.9286499, gradient norm = 0.0134139 (50 iterations in 5.064s)
# [t-SNE] Iteration 100: error = 84.1050339, gradient norm = 0.0065832 (50 iterations in 3.883s)
# [t-SNE] Iteration 150: error = 81.9914398, gradient norm = 0.0040775 (50 iterations in 3.714s)
# [t-SNE] Iteration 200: error = 81.2210617, gradient norm = 0.0031832 (50 iterations in 3.930s)
# [t-SNE] Iteration 250: error = 80.8264084, gradient norm = 0.0018650 (50 iterations in 4.183s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.826408
# [t-SNE] Iteration 300: error = 2.6954479, gradient norm = 0.0013005 (50 iterations in 4.026s)
# [t-SNE] Iteration 350: error = 2.1637361, gradient norm = 0.0005745 (50 iterations in 3.804s)
# [t-SNE] Iteration 400: error = 1.9144409, gradient norm = 0.0003475 (50 iterations in 4.039s)
# [t-SNE] Iteration 450: error = 1.7680899, gradient norm = 0.0002486 (50 iterations in 3.708s)
# [t-SNE] Iteration 500: error = 1.6745617, gradient norm = 0.0001942 (50 iterations in 3.393s)
# [t-SNE] Iteration 550: error = 1.6104842, gradient norm = 0.0001571 (50 iterations in 3.544s)
# [t-SNE] Iteration 600: error = 1.5638973, gradient norm = 0.0001330 (50 iterations in 3.723s)
# [t-SNE] Iteration 650: error = 1.5285665, gradient norm = 0.0001192 (50 iterations in 3.863s)
# [t-SNE] Iteration 700: error = 1.5008550, gradient norm = 0.0001046 (50 iterations in 3.654s)
# [t-SNE] Iteration 750: error = 1.4788116, gradient norm = 0.0000961 (50 iterations in 3.625s)
# [t-SNE] Iteration 800: error = 1.4613562, gradient norm = 0.0000881 (50 iterations in 4.012s)
# [t-SNE] Iteration 850: error = 1.4472429, gradient norm = 0.0000842 (50 iterations in 4.124s)
# [t-SNE] Iteration 900: error = 1.4356096, gradient norm = 0.0000819 (50 iterations in 3.722s)
# [t-SNE] Iteration 950: error = 1.4263830, gradient norm = 0.0000761 (50 iterations in 4.232s)
# [t-SNE] Iteration 1000: error = 1.4183620, gradient norm = 0.0000730 (50 iterations in 4.062s)
# [t-SNE] KL divergence after 1000 iterations: 1.418362
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\Love\anaconda3\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 1.921s...
# [t-SNE] Computed neighbors for 7352 samples in 52.416s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.789s
# [t-SNE] Iteration 50: error = 85.4975586, gradient norm = 0.0286723 (50 iterations in 7.375s)
# [t-SNE] Iteration 100: error = 76.1439056, gradient norm = 0.0049451 (50 iterations in 8.063s)
# [t-SNE] Iteration 150: error = 74.9624100, gradient norm = 0.0029795 (50 iterations in 7.095s)
# [t-SNE] Iteration 200: error = 74.4928970, gradient norm = 0.0016188 (50 iterations in 6.813s)
# [t-SNE] Iteration 250: error = 74.2660370, gradient norm = 0.0011793 (50 iterations in 6.352s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.266037
# [t-SNE] Iteration 300: error = 2.1821673, gradient norm = 0.0012163 (50 iterations in 5.728s)
# [t-SNE] Iteration 350: error = 1.7803743, gradient norm = 0.0004956 (50 iterations in 5.113s)
# [t-SNE] Iteration 400: error = 1.6078387, gradient norm = 0.0002878 (50 iterations in 4.794s)
# [t-SNE] Iteration 450: error = 1.5114322, gradient norm = 0.0001943 (50 iterations in 5.041s)
# [t-SNE] Iteration 500: error = 1.4493762, gradient norm = 0.0001439 (50 iterations in 5.068s)
# [t-SNE] Iteration 550: error = 1.4066617, gradient norm = 0.0001210 (50 iterations in 4.787s)
# [t-SNE] Iteration 600: error = 1.3754739, gradient norm = 0.0001035 (50 iterations in 4.836s)
# [t-SNE] Iteration 650: error = 1.3530772, gradient norm = 0.0000906 (50 iterations in 5.137s)
# [t-SNE] Iteration 700: error = 1.3370749, gradient norm = 0.0000790 (50 iterations in 4.809s)
# [t-SNE] Iteration 750: error = 1.3249720, gradient norm = 0.0000713 (50 iterations in 4.775s)
# [t-SNE] Iteration 800: error = 1.3158302, gradient norm = 0.0000676 (50 iterations in 5.287s)
# [t-SNE] Iteration 850: error = 1.3086257, gradient norm = 0.0000640 (50 iterations in 5.015s)
# [t-SNE] Iteration 900: error = 1.3027505, gradient norm = 0.0000611 (50 iterations in 4.948s)
# [t-SNE] Iteration 950: error = 1.2977016, gradient norm = 0.0000579 (50 iterations in 5.314s)
# [t-SNE] Iteration 1000: error = 1.2934422, gradient norm = 0.0000541 (50 iterations in 5.365s)
# [t-SNE] KL divergence after 1000 iterations: 1.293442
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\Love\anaconda3\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# # Machine Learning Modeling

# %% [markdown]
# ## Defining few functions for modelling, prediction and evaluation

# %% [markdown]
# ### Function to plot the confusion matrix

# %%
# Labels that are useful in plotting confusion matrix
labels=['LAYING', 'SITTING','STANDING','WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS']

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
plt.rcParams["font.family"] = 'DejaVu Sans'

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ### Generic function to run any model specified

# %%
from datetime import datetime
def perform_model(model, X_train, y_train, X_test, y_test, class_labels, cm_normalize=True, \
                 print_cm=True, cm_cmap=plt.cm.Greens):
    
    
    # to store results at various phases
    results = dict()
    
    # time at which model starts training 
    train_start_time = datetime.now()
    print('training the model..')
    model.fit(X_train, y_train)
    print('Done \n \n')
    train_end_time = datetime.now()
    results['training_time'] =  train_end_time - train_start_time
    print('training_time(HH:MM:SS.ms) - {}\n\n'.format(results['training_time']))
    
    
    # predict test data
    print('Predicting test data')
    test_start_time = datetime.now()
    y_pred = model.predict(X_test)
    test_end_time = datetime.now()
    print('Done \n \n')
    results['testing_time'] = test_end_time - test_start_time
    print('testing time(HH:MM:SS:ms) - {}\n\n'.format(results['testing_time']))
    results['predicted'] = y_pred
   

    # calculate overall accuracty of the model
    accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_pred)
    # store accuracy in results
    results['accuracy'] = accuracy
    print('---------------------')
    print('|      Accuracy      |')
    print('---------------------')
    print('\n    {}\n\n'.format(accuracy))
    
    
    # confusion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    results['confusion_matrix'] = cm
    if print_cm: 
        print('--------------------')
        print('| Confusion Matrix |')
        print('--------------------')
        print('\n {}'.format(cm))
        
    # plot confusin matrix
    plt.figure(figsize=(8,8))
    plt.grid(b=False)
    plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
    plt.show()
    
    # get classification report
    print('-------------------------')
    print('| Classifiction Report |')
    print('-------------------------')
    classification_report = metrics.classification_report(y_test, y_pred)
    # store report in results
    results['classification_report'] = classification_report
    print(classification_report)
    
    # add the trained  model to the results
    results['model'] = model
    
    return results

# %% [markdown]
# ### Method to print the gridsearch Attributes

# %%
def print_grid_search_attributes(model):
    # Estimator that gave highest score among all the estimators formed in GridSearch
    print('--------------------------')
    print('|      Best Estimator     |')
    print('--------------------------')
    print('\n\t{}\n'.format(model.best_estimator_))


    # parameters that gave best results while performing grid search
    print('--------------------------')
    print('|     Best parameters     |')
    print('--------------------------')
    print('\tParameters of best estimator : \n\n\t{}\n'.format(model.best_params_))


    #  number of cross validation splits
    print('---------------------------------')
    print('|   No of CrossValidation sets   |')
    print('--------------------------------')
    print('\n\tTotal numbre of cross validation sets: {}\n'.format(model.n_splits_))


    # Average cross validated score of the best estimator, from the Grid Search 
    print('--------------------------')
    print('|        Best Score       |')
    print('--------------------------')
    print('\n\tAverage Cross Validate scores of best estimator : \n\n\t{}\n'.format(model.best_score_))

# %% [markdown]
# ## Logistic Regression with Grid Search

# %%
from sklearn import linear_model
from sklearn import metrics

from sklearn.model_selection import GridSearchCV

# %%
# start Grid search
parameters = {'C':[0.01, 0.1, 1, 10, 20, 30], 'penalty':['l2','l1']}
log_reg = linear_model.LogisticRegression()
log_reg_grid = GridSearchCV(log_reg, param_grid=parameters, cv=3, verbose=1, n_jobs=-1)
log_reg_grid_results =  perform_model(log_reg_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:   24.4s finished
# C:\Users\Love\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:00:29.963880
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.036389
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9575839837122497
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 429  59   0   0   3]
#  [  0  16 516   0   0   0]
#  [  0   0   0 492   3   1]
#  [  0   0   0   4 403  13]
#  [  0   0   0  25   1 445]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.96      0.87      0.92       491
#           STANDING       0.90      0.97      0.93       532
#            WALKING       0.94      0.99      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.96      0.97       420
#   WALKING_UPSTAIRS       0.96      0.94      0.95       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %%
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(log_reg_grid_results['confusion_matrix'], classes=labels, cmap=plt.cm.Greens, )
plt.show()

# %%
# observe the attributes of the model 
print_grid_search_attributes(log_reg_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 1, 'penalty': 'l2'}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 3
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9374335617559958

# %% [markdown]
# ## Linear SVC with GridSearch

# %%
from sklearn.svm import LinearSVC

# %%
parameters = {'C':[0.125, 0.5, 1, 2, 8, 16]}
lr_svc = LinearSVC(tol=0.00005)
lr_svc_grid = GridSearchCV(lr_svc, param_grid=parameters, n_jobs=-1, verbose=1)
lr_svc_grid_results = perform_model(lr_svc_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  2.0min finished
# C:\Users\Love\anaconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:02:10.789307
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.009000
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9667458432304038
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  2 428  58   0   0   3]
#  [  0   9 522   1   0   0]
#  [  0   0   0 496   0   0]
#  [  0   0   0   3 412   5]
#  [  0   0   0  17   0 454]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.98      0.87      0.92       491
#           STANDING       0.90      0.98      0.94       532
#            WALKING       0.96      1.00      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       420
#   WALKING_UPSTAIRS       0.98      0.96      0.97       471
#
#           accuracy                           0.97      2947
#          macro avg       0.97      0.97      0.97      2947
#       weighted avg       0.97      0.97      0.97      2947

# %%
print_grid_search_attributes(lr_svc_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=5e-05,
#           verbose=0)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 0.5}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9423364179118282

# %% [markdown]
# ## Kernel SVM with GridSearch

# %%
from sklearn.svm import SVC
parameters = {'C':[2,8,16],
              'gamma': [ 0.0078125, 0.125, 2]}
rbf_svm = SVC(kernel='rbf')
rbf_svm_grid = GridSearchCV(rbf_svm,param_grid=parameters, n_jobs=-1)
rbf_svm_grid_results = perform_model(rbf_svm_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:13:04.781740
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:03.903211
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9626739056667798
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 441  48   0   0   2]
#  [  0  12 520   0   0   0]
#  [  0   0   0 489   2   5]
#  [  0   0   0   4 397  19]
#  [  0   0   0  17   1 453]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.97      0.90      0.93       491
#           STANDING       0.92      0.98      0.95       532
#            WALKING       0.96      0.99      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.95      0.97       420
#   WALKING_UPSTAIRS       0.95      0.96      0.95       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %%
print_grid_search_attributes(rbf_svm_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	SVC(C=16, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.0078125, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 16, 'gamma': 0.0078125}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9447834551903698

# %% [markdown]
# ## Decision Trees with GridSearchCV

# %%
from sklearn.tree import DecisionTreeClassifier
parameters = {'max_depth':np.arange(3,10,2)}
dt = DecisionTreeClassifier()
dt_grid = GridSearchCV(dt,param_grid=parameters, n_jobs=-1)
dt_grid_results = perform_model(dt_grid, X_train, y_train, X_test, y_test, class_labels=labels)
print_grid_search_attributes(dt_grid_results['model'])
# Out:
# training the model..
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:00:42.407981
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.011993
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8737699355276553
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 374 117   0   0   0]
#  [  0  60 472   0   0   0]
#  [  0   0   0 468  20   8]
#  [  0   0   0  23 351  46]
#  [  0   0   0  51  47 373]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.86      0.76      0.81       491
#           STANDING       0.80      0.89      0.84       532
#            WALKING       0.86      0.94      0.90       496
# WALKING_DOWNSTAIRS       0.84      0.84      0.84       420
#   WALKING_UPSTAIRS       0.87      0.79      0.83       471
#
#           accuracy                           0.87      2947
#          macro avg       0.87      0.87      0.87      2947
#       weighted avg       0.88      0.87      0.87      2947
#
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=9, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'max_depth': 9}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.8495735697406086

# %% [markdown]
# ## Random Forest Classifier with GridSearch

# %%
from sklearn.ensemble import RandomForestClassifier
params = {'n_estimators': np.arange(10,201,20), 'max_depth':np.arange(3,15,2)}
rfc = RandomForestClassifier()
rfc_grid = GridSearchCV(rfc, param_grid=params, n_jobs=-1)
rfc_grid_results = perform_model(rfc_grid, X_train, y_train, X_test, y_test, class_labels=labels)
print_grid_search_attributes(rfc_grid_results['model'])
# Out:
# training the model..
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:20:48.219893
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.109372
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9297590770274856
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 436  55   0   0   0]
#  [  0  41 491   0   0   0]
#  [  0   0   0 486   7   3]
#  [  0   0   0  20 359  41]
#  [  0   0   0  34   6 431]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.91      0.89      0.90       491
#           STANDING       0.90      0.92      0.91       532
#            WALKING       0.90      0.98      0.94       496
# WALKING_DOWNSTAIRS       0.97      0.85      0.91       420
#   WALKING_UPSTAIRS       0.91      0.92      0.91       471
#
#           accuracy                           0.93      2947
#          macro avg       0.93      0.93      0.93      2947
#       weighted avg       0.93      0.93      0.93      2947
#
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=13, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=130,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'max_depth': 13, 'n_estimators': 130}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9212504797976294

# %% [markdown]
# ## Gradient Boosted Decision Trees With GridSearch

# %%
from sklearn.ensemble import GradientBoostingClassifier
param_grid = {'max_depth': [140], 
             'n_estimators':[5]}
gbdt = GradientBoostingClassifier()
gbdt_grid = GridSearchCV(gbdt, param_grid=param_grid, n_jobs=-1)
gbdt_grid_results = perform_model(gbdt_grid, X_train, y_train, X_test, y_test, class_labels=labels)
print_grid_search_attributes(gbdt_grid_results['model'])
# Out:
# training the model..
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:06:51.760539
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.019992
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8062436375975568
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [ 26 352 110   0   0   3]
#  [ 35  49 444   3   0   1]
#  [ 38   0   0 408  14  36]
#  [ 58   0   1  11 310  40]
#  [ 99   1   0  36  10 325]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       0.68      1.00      0.81       537
#            SITTING       0.88      0.72      0.79       491
#           STANDING       0.80      0.83      0.82       532
#            WALKING       0.89      0.82      0.86       496
# WALKING_DOWNSTAIRS       0.93      0.74      0.82       420
#   WALKING_UPSTAIRS       0.80      0.69      0.74       471
#
#           accuracy                           0.81      2947
#          macro avg       0.83      0.80      0.81      2947
#       weighted avg       0.82      0.81      0.81      2947
#
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=140,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=5,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'max_depth': 140, 'n_estimators': 5}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.8165178947173702

# %% [markdown]
# # Comparing all the models

# %%
print('\n                     Accuracy     Error')
print('                     ----------   --------')
print('Logistic Regression : {:.04}%       {:.04}%'.format(log_reg_grid_results['accuracy'] * 100,\
                                                  100-(log_reg_grid_results['accuracy'] * 100)))

print('Linear SVC          : {:.04}%       {:.04}% '.format(lr_svc_grid_results['accuracy'] * 100,\
                                                        100-(lr_svc_grid_results['accuracy'] * 100)))

print('rbf SVM classifier  : {:.04}%      {:.04}% '.format(rbf_svm_grid_results['accuracy'] * 100,\
                                                          100-(rbf_svm_grid_results['accuracy'] * 100)))

print('DecisionTree        : {:.04}%      {:.04}% '.format(dt_grid_results['accuracy'] * 100,\
                                                        100-(dt_grid_results['accuracy'] * 100)))

print('Random Forest       : {:.04}%      {:.04}% '.format(rfc_grid_results['accuracy'] * 100,\
                                                           100-(rfc_grid_results['accuracy'] * 100)))
print('GradientBoosting DT : {:.04}%      {:.04}% '.format(rfc_grid_results['accuracy'] * 100,\
                                                        100-(rfc_grid_results['accuracy'] * 100)))
# Out:
#                      Accuracy     Error
#                      ----------   --------
# Logistic Regression : 95.76%       4.242%
# Linear SVC          : 96.67%       3.325%
# rbf SVM classifier  : 96.27%      3.733%
# DecisionTree        : 87.38%      12.62%
# Random Forest       : 92.98%      7.024%
# GradientBoosting DT : 92.98%      7.024%

# %% [markdown]
# ## Conclusion: We can choose ___Logistic regression___ or ___Linear SVC___ or ___rbf SVM___.

# %% [markdown]
# # Deep Learning Models

# %% [markdown]
# ## Defining few utilities and Functions

# %%
import pandas as pd 
import numpy as np

# %%
# Activities are the class labels
# It is a 6 class classification
ACTIVITIES = {
    0: 'WALKING',
    1: 'WALKING_UPSTAIRS',
    2: 'WALKING_DOWNSTAIRS',
    3: 'SITTING',
    4: 'STANDING',
    5: 'LAYING',
}

# Utility function to print the confusion matrix
def confusion_matrix(Y_true, Y_pred):
    Y_true = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_true, axis=1)])
    Y_pred = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_pred, axis=1)])

    return pd.crosstab(Y_true, Y_pred, rownames=['True'], colnames=['Pred'])

# %%
# Data directory
DATADIR = 'UCI_HAR_Dataset'

# %%
# Raw data signals
# Signals are from Accelerometer and Gyroscope
# The signals are in x,y,z directions
# Sensor signals are filtered to have only body acceleration
# excluding the acceleration due to gravity
# Triaxial acceleration from the accelerometer is total acceleration
SIGNALS = [
    "body_acc_x",
    "body_acc_y",
    "body_acc_z",
    "body_gyro_x",
    "body_gyro_y",
    "body_gyro_z",
    "total_acc_x",
    "total_acc_y",
    "total_acc_z"
]

# %%
# Utility function to read the data from csv file
def _read_csv(filename):
    return pd.read_csv(filename, delim_whitespace=True, header=None)

# Utility function to load the load
def load_signals(subset):
    signals_data = []

    for signal in SIGNALS:
        filename = f'UCI_HAR_Dataset/{subset}/Inertial Signals/{signal}_{subset}.txt'
        signals_data.append(
            _read_csv(filename).to_numpy()
        ) 

    # Transpose is used to change the dimensionality of the output,
    # aggregating the signals by combination of sample/timestep.
    # Resultant shape is (7352 train/2947 test samples, 128 timesteps, 9 signals)
    return np.transpose(signals_data, (1, 2, 0))

# %%
pwd
# Out:
# 'C:\\Users\\Love\\Data Science\\Assignments\\Project2'

# %%
def load_y(subset):
    """
    The objective that we are trying to predict is a integer, from 1 to 6,
    that represents a human activity. We return a binary representation of 
    every sample objective as a 6 bits vector using One Hot Encoding
    (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)
    """
    filename = f'UCI_HAR_Dataset/{subset}/y_{subset}.txt'
    y = _read_csv(filename)[0]

    return pd.get_dummies(y).to_numpy()

# %%
def load_data():
    """
    Obtain the dataset from multiple files.
    Returns: X_train, X_test, y_train, y_test
    """
    X_train, X_test = load_signals('train'), load_signals('test')
    y_train, y_test = load_y('train'), load_y('test')

    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Library Imports

# %%
# Importing tensorflow
np.random.seed(42)
import tensorflow as tf
tf.random.set_seed(42)

# %%
# # Configuring a session
# session_conf = tf.compat.v1.ConfigProto(
#     intra_op_parallelism_threads=1,
#     inter_op_parallelism_threads=1
# )

# %%
# # Import Keras
# from keras import backend as K
# sess = tf.compat.v1.Session(graph=tf.get_default_graph(), config=session_conf)
# K.set_session(sess)

# %%
# Importing libraries
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers.core import Dense, Dropout

# %% [markdown]
# ## Initializing parameters

# %%
# Initializing parameters
epochs = 30
batch_size = 16
n_hidden = 32

# %%
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Loading the train and test data
X_train, X_test, Y_train, Y_test = load_data()

# %%
timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)

print(timesteps)
print(input_dim)
print(len(X_train))
# Out:
# 128
# 9
# 7352

# %% [markdown]
# ## Defining the Architecture of LSTM

# %%
# Initiliazing the sequential model
model = Sequential()
# Configuring the parameters
model.add(LSTM(n_hidden, input_shape=(timesteps, input_dim)))
# Adding a dropout layer
model.add(Dropout(0.5))
# Adding a dense output layer with sigmoid activation
model.add(Dense(n_classes, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 32)                5376
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 198
# =================================================================
# Total params: 5,574
# Trainable params: 5,574
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Training the model
model.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_data=(X_test, Y_test),
          epochs=epochs)
# Out:
# Epoch 1/30
# 460/460 [==============================] - 22s 48ms/step - loss: 1.4024 - accuracy: 0.3653 - val_loss: 1.2852 - val_accuracy: 0.4910
# Epoch 2/30
# 460/460 [==============================] - 26s 56ms/step - loss: 1.1176 - accuracy: 0.5159 - val_loss: 1.0714 - val_accuracy: 0.5612
# Epoch 3/30
# 460/460 [==============================] - 26s 56ms/step - loss: 0.8685 - accuracy: 0.6220 - val_loss: 0.8503 - val_accuracy: 0.6054
# Epoch 4/30
# 460/460 [==============================] - 23s 51ms/step - loss: 0.8066 - accuracy: 0.6443 - val_loss: 0.8179 - val_accuracy: 0.6318
# Epoch 5/30
# 460/460 [==============================] - 23s 49ms/step - loss: 0.6878 - accuracy: 0.6914 - val_loss: 0.8191 - val_accuracy: 0.6641
# Epoch 6/30
# 460/460 [==============================] - 23s 50ms/step - loss: 0.6479 - accuracy: 0.7153 - val_loss: 0.7802 - val_accuracy: 0.6709
# Epoch 7/30
# 460/460 [==============================] - 27s 59ms/step - loss: 0.6451 - accuracy: 0.7069 - val_loss: 0.6883 - val_accuracy: 0.7044
# Epoch 8/30
# 460/460 [==============================] - 31s 67ms/step - loss: 0.6014 - accuracy: 0.7334 - val_loss: 0.7829 - val_accuracy: 0.7055
# Epoch 9/30
# 460/460 [==============================] - 30s 66ms/step - loss: 0.5513 - accuracy: 0.7626 - val_loss: 0.6728 - val_accuracy: 0.7754
# Epoch 10/30
# 460/460 [==============================] - 24s 53ms/step - loss: 0.5385 - accuracy: 0.7905 - val_loss: 0.6845 - val_accuracy: 0.7818
# Epoch 11/30
# 460/460 [==============================] - 29s 63ms/step - loss: 0.4704 - accuracy: 0.8297 - val_loss: 0.6624 - val_accuracy: 0.8113
# Epoch 12/30
# 460/460 [==============================] - 30s 65ms/step - loss: 0.4154 - accuracy: 0.8634 - val_loss: 0.7606 - val_accuracy: 0.7842
# Epoch 13/30
# 460/460 [==============================] - 32s 69ms/step - loss: 0.3639 - accuracy: 0.8851 - val_loss: 0.6369 - val_accuracy: 0.7974
# Epoch 14/30
# 460/460 [==============================] - 27s 59ms/step - loss: 0.3174 - accuracy: 0.9021 - val_loss: 0.3901 - val_accuracy: 0.8721
# Epoch 15/30
# 460/460 [==============================] - 25s 53ms/step - loss: 0.3083 - accuracy: 0.9071 - val_loss: 0.4908 - val_accuracy: 0.8510
# Epoch 16/30
# 460/460 [==============================] - 27s 59ms/step - loss: 0.2755 - accuracy: 0.9189 - val_loss: 0.4813 - val_accuracy: 0.8683
# Epoch 17/30
# 460/460 [==============================] - 24s 53ms/step - loss: 0.2425 - accuracy: 0.9253 - val_loss: 0.4031 - val_accuracy: 0.8839
# Epoch 18/30
# 460/460 [==============================] - 25s 55ms/step - loss: 0.2458 - accuracy: 0.9225 - val_loss: 0.3436 - val_accuracy: 0.8870
# Epoch 19/30
# 460/460 [==============================] - 30s 64ms/step - loss: 0.2316 - accuracy: 0.9312 - val_loss: 0.3848 - val_accuracy: 0.8945
# Epoch 20/30
# 460/460 [==============================] - 22s 48ms/step - loss: 0.2059 - accuracy: 0.9372 - val_loss: 0.4093 - val_accuracy: 0.8775
# Epoch 21/30
# 460/460 [==============================] - 27s 59ms/step - loss: 0.2190 - accuracy: 0.9365 - val_loss: 0.3205 - val_accuracy: 0.8968
# Epoch 22/30
# 460/460 [==============================] - 33s 71ms/step - loss: 0.2138 - accuracy: 0.9355 - val_loss: 0.2884 - val_accuracy: 0.9070
# Epoch 23/30
# 460/460 [==============================] - 27s 58ms/step - loss: 0.1902 - accuracy: 0.9388 - val_loss: 0.3167 - val_accuracy: 0.9063
# Epoch 24/30
# 460/460 [==============================] - 22s 48ms/step - loss: 0.1811 - accuracy: 0.9410 - val_loss: 0.3172 - val_accuracy: 0.8996
# Epoch 25/30
# 460/460 [==============================] - 26s 57ms/step - loss: 0.1639 - accuracy: 0.9433 - val_loss: 0.3686 - val_accuracy: 0.9050
# Epoch 26/30
# 460/460 [==============================] - 23s 50ms/step - loss: 0.1809 - accuracy: 0.9418 - val_loss: 0.3827 - val_accuracy: 0.9111
# Epoch 27/30
# 460/460 [==============================] - 24s 53ms/step - loss: 0.1676 - accuracy: 0.9452 - val_loss: 0.3312 - val_accuracy: 0.8856
# Epoch 28/30
# 460/460 [==============================] - 23s 50ms/step - loss: 0.1805 - accuracy: 0.9425 - val_loss: 0.4313 - val_accuracy: 0.8992
# Epoch 29/30
# 460/460 [==============================] - 24s 53ms/step - loss: 0.1574 - accuracy: 0.9460 - val_loss: 0.3028 - val_accuracy: 0.9101
# Epoch 30/30
# 460/460 [==============================] - 23s 50ms/step - loss: 0.1983 - accuracy: 0.9382 - val_loss: 0.3197 - val_accuracy: 0.9013

# %%
# Confusion Matrix
print(confusion_matrix(Y_test, model.predict(X_test)))
# Out:
# Pred                LAYING  SITTING  STANDING  WALKING  WALKING_DOWNSTAIRS  \
# True
# LAYING                 510        0         0        0                   0
# SITTING                  0      417        74        0                   0
# STANDING                 0      101       426        4                   0
# WALKING                  0        0         0      449                  28
# WALKING_DOWNSTAIRS       0        0         0        0                 419
# WALKING_UPSTAIRS         0        2         0       19                  15
#
# Pred                WALKING_UPSTAIRS
# True
# LAYING                            27
# SITTING                            0
# STANDING                           1
# WALKING                           19
# WALKING_DOWNSTAIRS                 1
# WALKING_UPSTAIRS                 435

# %%
score = model.evaluate(X_test, Y_test)
# Out:
# 93/93 [==============================] - 1s 12ms/step - loss: 0.3197 - accuracy: 0.9013

# %%
score
# Out:
# [0.3197280466556549, 0.9012554883956909]

# %% [markdown]
# ## Conclusion
# With a simple 2 layer architecture we got 90.09% accuracy and a loss of 0.30
# We can further imporve the performace with Hyperparameter tuning
